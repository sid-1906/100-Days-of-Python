# %% [markdown]
# <h2 style="text-align:left;">
#     2237001
#     <span style="float:right;">
#         Jagtap Vishakha
#     </span>
# </h2>
# <h2 align="center">SL-II (DS)</h2>
# <h2 align="center">Assignment 02</h2>

# %% [markdown]
# ## Data Wrangling II
# Create an “Academic performance” dataset of students and perform the following operations using
# Python.
# 1. Scan all variables for missing values and inconsistencies. If there are missing values and/or
# inconsistencies, use any of the suitable techniques to deal with them.
# 2. Scan all numeric variables for outliers. If there are outliers, use any of the suitable techniques
# to deal with them.
# 3. Apply data transformations on at least one of the variables. The purpose of this
# transformation should be one of the following reasons: to change the scale for better
# understanding of the variable, to convert a non-linear relation into a linear one, or to decrease
# the skewness and convert the distribution into a normal distribution.

# %% [markdown]
# ### 1. Scan all variables for missing values and inconsistencies. If there are missing values and/or inconsistencies, use any of the suitable techniques to deal with them.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("dataset.csv")

# %%
df
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   NaN
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   NaN
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df.isnull()
# Out:
#     Roll_no   Name    ANN     CN     DS     AI   DBMS
# 0     False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False
# 5     False  False  False  False  False  False  False
# 6     False  False  False  False  False  False  False
# 7     False  False  False  False  False  False   True
# 8     False  False  False  False  False  False  False
# 9     False  False  False  False  False  False  False
# 10    False  False  False  False  False  False  False
# 11    False  False  False  False  False  False   True
# 12    False  False  False  False  False  False  False
# 13    False  False  False  False  False  False  False
# 14    False  False  False  False  False  False  False

# %%
df.notnull()
# Out:
#     Roll_no  Name   ANN    CN    DS    AI   DBMS
# 0      True  True  True  True  True  True   True
# 1      True  True  True  True  True  True   True
# 2      True  True  True  True  True  True   True
# 3      True  True  True  True  True  True   True
# 4      True  True  True  True  True  True   True
# 5      True  True  True  True  True  True   True
# 6      True  True  True  True  True  True   True
# 7      True  True  True  True  True  True  False
# 8      True  True  True  True  True  True   True
# 9      True  True  True  True  True  True   True
# 10     True  True  True  True  True  True   True
# 11     True  True  True  True  True  True  False
# 12     True  True  True  True  True  True   True
# 13     True  True  True  True  True  True   True
# 14     True  True  True  True  True  True   True

# %%
df.isnull().sum()
# Out:
# Roll_no    0
# Name       0
# ANN        0
# CN         0
# DS         0
# AI         0
# DBMS       2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll_no  15 non-null     int64
#  1   Name     15 non-null     object
#  2   ANN      15 non-null     int64
#  3   CN       15 non-null     int64
#  4   DS       15 non-null     int64
#  5   AI       15 non-null     int64
#  6   DBMS     13 non-null     float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 968.0+ bytes

# %%
bool_series = pd.notnull(df)
bool_series
# Out:
#     Roll_no  Name   ANN    CN    DS    AI   DBMS
# 0      True  True  True  True  True  True   True
# 1      True  True  True  True  True  True   True
# 2      True  True  True  True  True  True   True
# 3      True  True  True  True  True  True   True
# 4      True  True  True  True  True  True   True
# 5      True  True  True  True  True  True   True
# 6      True  True  True  True  True  True   True
# 7      True  True  True  True  True  True  False
# 8      True  True  True  True  True  True   True
# 9      True  True  True  True  True  True   True
# 10     True  True  True  True  True  True   True
# 11     True  True  True  True  True  True  False
# 12     True  True  True  True  True  True   True
# 13     True  True  True  True  True  True   True
# 14     True  True  True  True  True  True   True

# %%
df.fillna(0,inplace=True)
df
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   0.0
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   0.0
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1=pd.read_csv('dataset.csv')
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   NaN
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   NaN
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1.fillna(method ='pad')
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65  87.0
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34  53.0
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1=pd.read_csv('dataset.csv')
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   NaN
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   NaN
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1.fillna(method ='bfill')
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65  54.0
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   8.0
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1=pd.read_csv('dataset.csv')
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   NaN
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   NaN
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1["DBMS"].fillna(45, inplace = True)

# %%
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65  45.0
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34  45.0
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1=pd.read_csv('dataset.csv')
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   NaN
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   NaN
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1["DBMS"].fillna(int(df1["DBMS"].mean()), inplace=True)

# %%
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65  57.0
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34  57.0
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1=pd.read_csv('dataset.csv')
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   NaN
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   NaN
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1.replace(to_replace = np.nan, value = 85)
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65  85.0
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34  85.0
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1=pd.read_csv('dataset.csv')
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   NaN
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   NaN
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1.interpolate(method ='linear', limit_direction ='forward')
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65  70.5
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34  30.5
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1=pd.read_csv('dataset.csv')
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   NaN
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   NaN
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1.dropna()
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1=pd.read_csv('dataset.csv')
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   NaN
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   NaN
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1.dropna(how = 'all',inplace=True)

# %%
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   NaN
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   NaN
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1=pd.read_csv('dataset.csv')
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   NaN
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   NaN
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1.dropna(axis = 1)
# Out:
#     Roll_no       Name   ANN   CN   DS  AI
# 0         1  vaishnavi    88   79   56  76
# 1         2   vishakha    67   57  764  54
# 2         3      vinay    75   75   56  76
# 3         4      akash    76   79    8  65
# 4         5    samarth    56   97   67  45
# 5         6     vedant     7   87   56  87
# 6         7    utkarsh    56   57   45  78
# 7         8      soham     4   78   87  65
# 8         9     vishal  6463   56   67  76
# 9        10      abhay     6  556   54  89
# 10       11      vikas     6   45   87  89
# 11       12     pramod    46    8   67  34
# 12       13     prasad    67   75   34  65
# 13       14    nishant    67   14    9   8
# 14       15     pranay    64   45   98  45

# %%
df1=pd.read_csv('dataset.csv')
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   NaN
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   NaN
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df2 = df1.dropna(axis = 0, how ='any')

# %%
df2
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %%
df1=pd.read_csv('dataset.csv')
df1
# Out:
#     Roll_no       Name   ANN   CN   DS  AI  DBMS
# 0         1  vaishnavi    88   79   56  76  65.0
# 1         2   vishakha    67   57  764  54  54.0
# 2         3      vinay    75   75   56  76  67.0
# 3         4      akash    76   79    8  65  63.0
# 4         5    samarth    56   97   67  45  56.0
# 5         6     vedant     7   87   56  87  53.0
# 6         7    utkarsh    56   57   45  78  87.0
# 7         8      soham     4   78   87  65   NaN
# 8         9     vishal  6463   56   67  76  54.0
# 9        10      abhay     6  556   54  89  68.0
# 10       11      vikas     6   45   87  89  53.0
# 11       12     pramod    46    8   67  34   NaN
# 12       13     prasad    67   75   34  65   8.0
# 13       14    nishant    67   14    9   8  54.0
# 14       15     pranay    64   45   98  45  65.0

# %% [markdown]
# # OUTLIERS

# %%
# Importing
import sklearn
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Visualization

# %%
# Box Plot
import seaborn as sns
sns.boxplot(df1['DBMS'])
# Out:
# /home/vishakha/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DBMS'>

# %%
print(np.where(df1['DBMS']<50))
# Out:
# (array([12]),)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll_no  15 non-null     int64
#  1   Name     15 non-null     object
#  2   ANN      15 non-null     int64
#  3   CN       15 non-null     int64
#  4   DS       15 non-null     int64
#  5   AI       15 non-null     int64
#  6   DBMS     13 non-null     float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 968.0+ bytes

# %% [markdown]
# # Using ScatterPlot

# %%
# Scatter plot
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df1['DBMS'], df1['Name'])
plt.show()

# %%
print(np.where((df1['DBMS']<50)))
# Out:
# (array([12]),)

# %% [markdown]
# # 2. Z-score

# %%
from scipy import stats
import numpy as np 
z = np.abs(stats.zscore(df1['AI']))
print(z)
# Out:
# 0     0.569551
# 1     0.430192
# 2     0.569551
# 3     0.069679
# 4     0.839178
# 5     1.069422
# 6     0.660436
# 7     0.069679
# 8     0.569551
# 9     1.160308
# 10    1.160308
# 11    1.339050
# 12    0.069679
# 13    2.520564
# 14    0.839178
# Name: AI, dtype: float64

# %%
threshold = 1.000000
 
# Position of the outlier
print(np.where(z > 3))
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# # 3. IQR (Inter Quartile Range)

# %%
Q1 = np.percentile(df1['AI'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df1['AI'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1

# %%
IQR
# Out:
# 27.5

# %%
# Above Upper bound
upper = df1['AI'] >= (Q3+1.5*IQR)
 
print("Upper bound:",upper)
print(np.where(upper))
 
# Below Lower bound
lower = df1['AI'] <= (Q1-1.5*IQR)
print("Lower bound:", lower)
print(np.where(lower))
# Out:
# Upper bound: 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 14    False
# Name: AI, dtype: bool
# (array([], dtype=int64),)
# Lower bound: 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 14    False
# Name: AI, dtype: bool
# (array([], dtype=int64),)

# %% [markdown]
# # Removing the outliers

# %%
print("Old Shape: ", df1.shape)
upper = np.where(df1['AI'] >= (Q3+1.5*IQR))
lower = np.where(df1['AI'] <= (Q1-1.5*IQR))

''' Removing the Outliers '''
df1.drop(upper[0], inplace = True)
df1.drop(lower[0], inplace = True)

print("New Shape: ", df1.shape)
# Out:
# Old Shape:  (15, 7)
# New Shape:  (14, 7)

# %% [markdown]
# # data transformations

# %%
result = df1.transform(func = ['sqrt', 'exp'])
result
# Out:
# /home/vishakha/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_5176/3627700692.py:1: FutureWarning: ['Name'] did not transform successfully. If any error is raised, this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   result = df1.transform(func = ['sqrt', 'exp'])
#      Roll_no                      ANN                       CN                 \
#         sqrt           exp       sqrt           exp       sqrt            exp
# 0   1.000000  2.718282e+00   9.380832  1.651636e+38   8.888194   2.038281e+34
# 1   1.414214  7.389056e+00   8.185353  1.252363e+29   7.549834   5.685720e+24
# 2   1.732051  2.008554e+01   8.660254  3.733242e+32   8.660254   3.733242e+32
# 3   2.000000  5.459815e+01   8.717798  1.014800e+33   8.888194   2.038281e+34
# ...

# %% [markdown]
# # SCALING

# %% [markdown]
# # Method 1: Using Pandas and Numpy

# %%
data=pd.read_csv("iris.data")

# %%
data
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
data.rename(columns={'5.1': 'sepal_length', '3.5': 'sepal_width','1.4': 'petal_length','0.2': 'petal_width', 'Iris-setosa': 'Class'}, inplace=True)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           Class
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df2 = data.drop('Class', axis=1)
df_norm = (df2-df2.min())/(df2.max()-df2.min())
df_norm = pd.concat((df_norm, data.Class), 1)

print("Scaled Dataset Using Pandas")
df_norm.head()
# Out:
# Scaled Dataset Using Pandas
# /tmp/ipykernel_5176/3373526448.py:3: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df_norm = pd.concat((df_norm, data.Class), 1)
#    sepal_length  sepal_width  petal_length  petal_width        Class
# 0      0.166667     0.416667      0.067797     0.041667  Iris-setosa
# 1      0.111111     0.500000      0.050847     0.041667  Iris-setosa
# 2      0.083333     0.458333      0.084746     0.041667  Iris-setosa
# 3      0.194444     0.666667      0.067797     0.041667  Iris-setosa
# 4      0.305556     0.791667      0.118644     0.125000  Iris-setosa

# %%
df_norm.skew(axis = 0, skipna = True)
# Out:
# /tmp/ipykernel_5176/420315870.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_norm.skew(axis = 0, skipna = True)
# sepal_length    0.303098
# sepal_width     0.350101
# petal_length   -0.289459
# petal_width    -0.117808
# dtype: float64

# %%
df.skew(axis = 1, skipna = True)
# Out:
# /tmp/ipykernel_5176/2546390060.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew(axis = 1, skipna = True)
# 0    -1.795879
# 1     2.415094
# 2    -2.087711
# 3    -0.833676
# 4    -0.456279
# 5    -0.315315
# 6    -0.896379
# 7     0.102580
# 8     2.449059
# 9     2.319166
# 10   -0.039310
# 11    0.578028
# 12   -0.262145
# 13    1.036449
# 14    0.161451
# dtype: float64

# %% [markdown]
# For a unimodal distribution, negative skew commonly indicates that the tail is on the left side of the distribution, and positive skew indicates that the tail is on the right. In cases where one tail is long but the other tail is fat, skewness does not obey a simple rule. For example, a zero value means that the tails on both sides of the mean balance out overall; this is the case for a symmetric distribution, but can also be true for an asymmetric distribution where one tail is long and thin, and the other is short but fat.

# %% [markdown]
# # Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
  

  
# Calculating mean and standard deviation
mean = statistics.mean(df_norm["sepal_length"])
sd = statistics.stdev(df_norm["sepal_length"])
  
plt.plot(df_norm["sepal_length"], norm.pdf(df_norm["sepal_length"], mean, sd))
plt.show()
print(mean)
print(sd)
# Out:
# 0.430089485458613
# 0.23016501590711588

# %%
mean = statistics.mean(df_norm["petal_width"])
sd = statistics.stdev(df_norm["petal_width"])
  
plt.plot(df_norm["petal_width"], norm.pdf(df_norm["petal_width"], mean, sd))
plt.show()
print(mean)
print(sd)
# Out:
# 0.46057046979865773
# 0.3172050172458168

# %%
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

data = sns.load_dataset('iris')
print('Original Dataset')
data.head()

scaler = MinMaxScaler()

df_scaled = scaler.fit_transform(df2.to_numpy())
df_scaled = pd.DataFrame(df_scaled, columns=[
'sepal_length', 'sepal_width', 'petal_length', 'petal_width'])

print("Scaled Dataset Using MinMaxScaler")
df_scaled.head()
# Out:
# Original Dataset
# Scaled Dataset Using MinMaxScaler
#    sepal_length  sepal_width  petal_length  petal_width
# 0      0.166667     0.416667      0.067797     0.041667
# 1      0.111111     0.500000      0.050847     0.041667
# 2      0.083333     0.458333      0.084746     0.041667
# 3      0.194444     0.666667      0.067797     0.041667
# 4      0.305556     0.791667      0.118644     0.125000

# %%
mean = statistics.mean(df_scaled["sepal_length"])
sd = statistics.stdev(df_scaled["sepal_length"])
  
plt.plot(df_scaled["sepal_length"], norm.pdf(df_scaled["sepal_length"], mean, sd))
plt.show()
print(mean)
print(sd)
# Out:
# 0.430089485458613
# 0.23016501590711588

# %% [markdown]
# # Standardization

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import seaborn as sns

std_scaler = StandardScaler()

df_scaled = std_scaler.fit_transform(df2.to_numpy())
df_scaled = pd.DataFrame(df_scaled, columns=[
'sepal_length','sepal_width','petal_length','petal_width'])

print("Scaled Dataset Using StandardScaler")
df_scaled.head()
# Out:
# Scaled Dataset Using StandardScaler
#    sepal_length  sepal_width  petal_length  petal_width
# 0     -1.148356    -0.118060     -1.353964    -1.325063
# 1     -1.390542     0.344859     -1.410986    -1.325063
# 2     -1.511636     0.113399     -1.296943    -1.325063
# 3     -1.027262     1.270695     -1.353964    -1.325063
# 4     -0.542889     1.965072     -1.182901    -1.061466

# %% [markdown]
# Standardization doesn’t have any fixed minimum or maximum value. Here, the values of all the columns are scaled in such a way that they all have a mean equal to 0 and standard deviation equal to 1. This scaling technique works well with outliers. Thus, this technique is preferred if outliers are present in the dataset.
